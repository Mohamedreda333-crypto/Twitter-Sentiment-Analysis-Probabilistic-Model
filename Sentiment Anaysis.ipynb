# %% [markdown]
# # <p align="center">🧠 **Sentiment Analysis System Using Machine Learning and NLP** 🧠</p>

# %% [markdown]
# <p align="center">
#   <img src="https://www.altexsoft.com/static/blog-post/2024/4/9f5946d6-d060-4aaa-b1c3-e64795227a1c.webp" width="800"/>
# </p>

# %% [markdown]
# # **My Information**

# %% [markdown]
# ### ‎‧₊**˚✿[My Name]✿˚** : **[Mohamed Reda Ramadan Khamis]**
# ### ‎‧₊**˚✿[My Phone Number]✿˚** : **[01554725661]**

# %% [markdown]
# ## **Project Overview**
# This project focuses on building a Machine Learning model to classify textual data into different sentiment categories (Positive, Negative, Neutral).
# The workflow follows a complete NLP pipeline including preprocessing, feature engineering, model training, evaluation, and deployment preparation.
#
# ---
#
# ## **Objectives**
# - Perform advanced text preprocessing.
# - Apply feature extraction techniques (TF-IDF / Word Embeddings).
# - Train and evaluate multiple ML models.
# - Select the best-performing model.
# - Prepare the model for deployment using Streamlit.
#
# ---
#
# ## **Tech Stack**
# - Python
# - Pandas & NumPy
# - NLTK / Scikit-learn
# - Matplotlib / Seaborn
# - Streamlit (Deployment)

# %% [markdown]
# ## **Importing Modules**

# %%
import pandas as pd
import numpy as np
import math
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from nltk.stem import PorterStemmer
from sklearn.metrics import accuracy_score

# %%
train = pd.read_csv(r"F:\AI and ML Diploma\NLP\twitter_sentiment_analysis\twitter_training.csv",header=None)
test = pd.read_csv(r"F:\AI and ML Diploma\NLP\twitter_sentiment_analysis\twitter_validation.csv",header=None)

# %%
train.head()
# Out:
#       0            1         2  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#                                                    3
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...

# %%
train.nunique()
# Out:
# 0    12447
# 1       32
# 2        4
# 3    69491
# dtype: int64

# %% [markdown]
# # **Text Preprocessing**
#
# Text data requires cleaning before feeding it into Machine Learning models.
#
# The preprocessing pipeline includes:
# - Lowercasing
# - Removing punctuation
# - Removing stopwords
# - Lemmatization / Stemming
# - Removing special characters

# %%
train = train[(train[2]=='Positive') | (train[2]=='Negative')]
test = test[(test[2]=='Positive') | (test[2]=='Negative')]

# %%
train.dropna(inplace=True)
test.dropna(inplace=True)

# %%
tweet = train[3]
labels = train[2]

# %%
def clean_text(tweet):
    tweet= re.sub('(#|@)\w*',"",tweet) # remove hashtags and mentions
    tweet= re.sub("https?:\/\/\S+","",tweet) # remove links
    tweet= re.sub("(\?|!)+","",tweet) # remove question marks "???" or exclamatiomn marks "!!!"
    tweet= re.sub("\s\d+\s","",tweet) # remove numbers
    tweet= re.sub("(\.|\,)+","",tweet) # remove punctuation "." or ","
    tweet= re.sub("^\s+","",tweet)   # remove leading spaces (spaces at the beginning)
    tweet= re.sub("\s+$","",tweet) #  remove trailing spaces (spaces at the end)
    return tweet

# %%
tweets = tweet.apply(clean_text)

# %%
nltk.download('stopwords')
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %%
stop_words = set(stopwords.words('english'))

def process_sentence(tweets):
    clean_tweets=[]
    for tweet in tweets:
        tweet=clean_text(tweet)
        tweet=tweet.split()
        c_tweet=[word.lower() for word in tweet if word.lower() not in stop_words] #remove stop wods & convert to lower casee 
        #stemming 
        ps=PorterStemmer()
        clean_tweet=[ps.stem(word) for word in c_tweet]#convert word to  base 
        clean_tweets.append(clean_tweet)

    return clean_tweets

# %%
clean_tweets = process_sentence(tweets)

# %%
labels = pd.get_dummies(labels , drop_first=True)

# %% [markdown]
# ## **Building the Probabilistic Model**

# %%
def build_freqs (filtered_sentence, ys):

    yslist = np. squeeze(ys).tolist()

    freqs = {}
    for y, tweet in zip(yslist, filtered_sentence):
        for word in tweet:
            pair = (word, y)
            if pair in freqs:
                freqs [pair] += 1
            else:
                freqs [pair] = 1
    return freqs

# %%
freqs = build_freqs(clean_tweets,labels)

# %%
freqs
# Out:
# {('im', True): 182,
#  ('get', True): 1286,
#  ('borderland', True): 343,
#  ('murder', True): 39,
#  ('come', True): 560,
#  ('border', True): 25,
#  ('kill', True): 269,
#  ('borderlandsand', True): 23,
#  ('spent', True): 37,
#  ('hour', True): 126,
#  ('make', True): 665,
#  ('someth', True): 188,
#  ('fun', True): 911,
#  ('know', True): 507,
#  ('huge', True): 145,
#  ('fan', True): 163,
#  ('maya', True): 19,
#  ('one', True): 1064,
#  ('favorit', True): 380,
#  ('charact', True): 200,
#  ('decid', True): 81,
#  ('wallpap', True): 14,
#  ('pc', True): 146,
#  ('origin', True): 145,
#  ('imag', True): 24,
#  ('versu', True): 8,
#  ('creation', True): 5,
#  ('made', True): 295,
#  (':)', True): 65,
#  ('enjoy', True): 437,
#  ('pictwittercom/mlsi5wf9jg', True): 3,
#  ('coupl', True): 65,
#  ("i'm", True): 1188,
#  ("here'", True): 41,
#  ('pictur', True): 33,
#  ('compar', True): 37,
#  ('made:)', True): 1,
#  ('pictwittercom', True): 275,
#  ('/', True): 2181,
#  ('mlsi5wf9jg', True): 1,
#  ('rhandlerr', True): 582,
#  ('2010', True): 9,
#  ('first', True): 458,
#  ('session', True): 32,
#  ('long', True): 230,
#  ('time', True): 1096,
#  ('actual', True): 391,
#  ('realli', True): 1276,
#  ('satisfi', True): 35,
#  ('combat', True): 29,
#  ('experi', True): 140,
#  ('got', True): 588,
#  ('good', True): 1604,
#  ('fight', True): 68,
#  ('rather', True): 44,
#  ('real', True): 169,
#  ('nice', True): 533,
#  ('wait', True): 906,
#  ('hot', True): 87,
#  ('row', True): 34,
#  ('bad', True): 241,
#  ('biggest', False): 72,
#  ('dissappoin', False): 4,
#  ('life', False): 256,
#  ('came', False): 70,
#  ('year', False): 670,
#  ('ago', False): 137,
#  ('fuck', False): 2428,
#  ('borderland', False): 136,
#  ('3', False): 35,
#  ('disappoint', False): 216,
#  ('come', False): 386,
#  ('male', False): 7,
#  ('hang', False): 23,
#  ('time', False): 1034,
#  ('back', False): 657,
#  ('last', False): 334,
#  ('finish', True): 239,
#  ('borderlandsfin', True): 2,
#  ('ya', True): 42,
#  ('thank', True): 1279,
#  ('hang', True): 87,
#  ('everyon', True): 320,
#  ('tri', True): 232,
#  ('stream', True): 532,
#  ('tomorrow', True): 161,
#  ('might', True): 108,
#  ('irl', True): 12,
#  ('awayu', True): 3,
#  ('shall', True): 20,
#  ('see', True): 807,
#  ('much', True): 685,
#  ('raid', True): 78,
#  ('final', True): 551,
#  ('find', True): 94,
#  ('borderlandsy', True): 1,
#  ("i'll", True): 152,
#  ('mayb', True): 114,
#  ("we'll", True): 20,
#  ('mompou', True): 2,
#  ('_', True): 578,
#  ('mumpow', True): 2,
#  ('megamagwitch', True): 1,
#  ('kfdmitch', True): 1,
#  ('haircut', True): 1,
#  ('would', True): 504,
#  ('still', True): 692,
#  ('hawaii', True): 2,
#  ('megamagwif', True): 1,
#  ('fendmitch', True): 1,
#  ('borderlandsupd', True): 1,
#  ('guy', True): 371,
#  ('even', True): 394,
#  ('go', True): 1052,
#  ('hope', True): 309,
#  ('awayuw', True): 1,
#  ('never', True): 321,
#  ('hey', True): 96,
#  ('use', True): 376,
#  ('mani', True): 234,
#  ('man', False): 345,
#  ('gearbox', False): 14,
#  ('realli', False): 970,
#  ('need', False): 609,
#  ('fix', False): 1431,
#  ('dissapoint', False): 3,
#  ('drop', False): 230,
#  ('new', False): 764,
#  ('borderlandsdlc', False): 4,
#  ('cant', False): 225,
#  ('fine', False): 89,
#  ('farm', False): 32,
#  ('boss', False): 28,
#  ('mayhemto', False): 6,
#  ('getlegendari', False): 4,
#  ('anywher', False): 57,
#  ('els', False): 158,
#  ('get', False): 2311,
#  ('6-10', False): 5,
#  ('suck', False): 362,
#  ('alot', False): 6,
#  ('legendari', False): 13,
#  ('elsewher', False): 4,
#  ('disssapoint', False): 1,
#  ('bethesda', False): 9,
#  ('borderlandsit', False): 1,
#  ('complet', False): 249,
#  ('borderlandsday', False): 1,
#  ('dlc', False): 43,
#  ('e', False): 43,
#  ('foot', False): 20,
#  ('get-drop', False): 1,
#  ('<unk>', False): 315,
#  ('thisdrop', False): 1,
#  ('forc', False): 100,
#  ('everyon', False): 315,
#  ('like', False): 1585,
#  ('everi', False): 571,
#  ('slick', False): 17,
#  ('hair', False): 31,
#  ('haven’t', False): 54,
#  ('heard', False): 47,
#  ('bang', False): 5,
#  ('stupid', False): 312,
#  ('asshol', False): 45,
#  ('border', False): 6,
#  ('countri', False): 41,
#  ('fallen', False): 8,
#  ('alien', False): 8,
#  ('like<unk>', False): 1,
#  ('beth', False): 1,
#  ('’', False): 938,
#  ('enough', False): 152,
#  ('gray', False): 2,
#  ('practic', False): 34,
#  ('franc', False): 2,
#  ('greedi', False): 38,
#  ('borderlandstoday', True): 7,
#  ("i'v", True): 437,
#  ('new', True): 1164,
#  ('command', True): 29,
#  ('set', True): 127,
#  ('look', True): 1141,
#  ('forward', True): 226,
#  ('start', True): 334,
#  ('instal', True): 75,
#  ('event', True): 117,
#  ('abouthour', True): 11,
#  ('clean', True): 48,
#  ('volumetoday', True): 1,
#  ('awesom', True): 446,
#  ('server', True): 72,
#  ('imma', True): 22,
#  ('probabl', True): 163,
#  ('play', True): 2513,
#  ('tp', True): 12,
#  ('bit', True): 132,
#  ('live', True): 342,
#  ("that'yer", True): 1,
#  ('video', True): 344,
#  ('fuck', True): 721,
#  ('yessssssss', True): 3,
#  ('fick', True): 10,
#  ('yessssss', True): 2,
#  ('yessssssss<unk>', True): 1,
#  ('ground', False): 55,
#  ('almost', False): 207,
#  ('look', False): 670,
#  ('pretti', False): 127,
#  ('cool', False): 52,
#  ('even', False): 989,
#  ('despit', False): 80,
#  ('tier', False): 16,
#  ('unfunni', False): 6,
#  ('write', False): 45,
#  ('becam', False): 32,
#  ('yet', False): 218,
#  ('anoth', False): 313,
#  ('surviv', False): 24,
#  ('craft', False): 5,
#  ('game', False): 4468,
#  ('can’t', False): 243,
#  ('wait', False): 321,
#  ('shitti', False): 112,
#  ('trend', False): 17,
#  ('die', False): 224,
#  ('borderlin', False): 3,
#  ("can't", False): 754,
#  ('crappi', False): 36,
#  ('grosskreutz', False): 1,
#  ('spell', False): 9,
#  ('turn', False): 155,
#  ('crap', False): 127,
#  ('mod', False): 14,
#  ('deep', False): 20,
#  ('fifth', False): 2,
#  ('format', False): 26,
#  ('ultim', False): 50,
#  ('mobil', False): 246,
#  ('start', False): 409,
#  ('top', False): 106,
#  ('annoy', False): 239,
#  ('serious', False): 136,
#  ('submit', False): 18,
#  ('complaint', False): 34,
#  ('ceo', False): 13,
#  ('pay', False): 278,
#  ('staff', False): 28,
#  ('bonus', False): 13,
#  ('file', False): 70,
#  ('employe', False): 89,
#  ('competitor', False): 8,
#  ('suppos', False): 87,
#  ("isn'ain", False): 1,
#  ('entir', False): 120,
#  ('offer', False): 27,
#  ('fuckin', False): 60,
#  ('trash', False): 291,
#  ('damn', False): 556,
#  ('rubbish', False): 15,
#  ('thrash', False): 28,
#  ('shit', False): 1523,
#  ('35', False): 2,
#  ('borderlandsth', True): 13,
#  ('game', True): 3149,
#  ('great', True): 973,
#  ('almost', True): 123,
#  ('gun', True): 61,
#  ('feel', True): 499,
#  ('felt', True): 63,
#  ('like', True): 1418,
#  ('need', True): 283,
#  ('grind', True): 56,
#  ('stori', True): 249,
#  ('hand', True): 88,
#  ('say', True): 387,
#  ('eventu', True): 33,
#  ('cutscen', True): 12,
#  ('skip', True): 5,
#  ('weapon', True): 59,
#  ('funni', True): 76,
#  ('sequenc', True): 6,
#  ('skip:)', True): 1,
#  ('occasion', True): 4,
#  ('slip:)', True): 1,
#  ('open', True): 102,
#  ('anoth', True): 220,
#  ('yet', True): 128,
#  ('someon', True): 128,
#  ('serious', True): 61,
#  ('pretti', True): 309,
#  ('side', True): 41,
#  ('damn', True): 301,
#  ('endless', True): 4,
#  (':', True): 243,
#  (')', True): 164,
#  ('sure', True): 171,
#  ('oh', True): 232,
#  ("yes'm", True): 1,
#  ('extend', True): 11,
#  ('meet', True): 53,
#  ('love', True): 2049,
#  ('goddess', True): 5,
#  ('gambl', True): 11,
#  ('beauti', True): 316,
#  ('god', True): 222,
#  ('16', True): 2,
#  ('green', True): 11,
#  ('"what', False): 9,
#  ('bitch"', False): 5,
#  ('slut"', False): 1,
#  ('terribl', False): 205,
#  ('"', False): 193,
#  ('bitch', False): 103,
#  ('miracle"', False): 1,
#  ('ok', True): 111,
#  ('(also', True): 19,
#  ('bomb', True): 10,
#  ('baghdad', True): 4,
#  ('anyth', True): 92,
#  ('hype)', True): 4,
#  ('concept', True): 38,
#  ('a1', True): 9,
#  ('give', True): 275,
#  ('baghad', True): 1,
#  ('here)', True): 2,
#  ('take', True): 266,
#  ('sir', True): 13,
#  ('(', True): 150,
#  ('also', True): 428,
#  ('case', True): 30,
#  ('hype', True): 191,
#  ('earth', True): 13,
#  ('rpg', True): 34,
#  ('uninstal', True): 5,
#  ('space', True): 24,
#  ('room', True): 38,
#  ('3', True): 82,
#  ('delet', True): 15,
#  ('watch', True): 434,
#  ('bioshock', True): 16,
#  ('switch', True): 158,
#  ('bitch', True): 32,
#  ('count', True): 12,
#  ('desert', True): 5,
#  ('montana', True): 1,
#  ('platinum', True): 24,
#  ('best', True): 1077,
#  ('loot', True): 22,
#  ('booti', True): 2,
#  ('lot', True): 345,
#  ('rock', True): 53,
#  ('name', True): 89,
#  ('jump', True): 81,
#  ('earli', True): 94,
#  ('today', True): 503,
#  ('dlc', True): 78,
#  ('&', True): 563,
#  ('vibe', True): 46,
#  ('playlist', True): 13,
#  ('drop', True): 112,
#  ('qualiti', True): 38,
#  ('720p', True): 5,
#  ('differ', True): 132,
#  ('well', True): 422,
#  ('run', True): 188,
#  ('dumb', True): 19,
#  ('internet', True): 102,
#  ('lmao', True): 60,
#  ('twitchtv/heyitscece_', True): 3,
#  ('morn', True): 90,
#  ('vibrat', True): 2,
#  ('lower', True): 18,
#  ('stupid', True): 46,
#  ('twitchtv', True): 84,
#  ('heyitscec', True): 1,
#  ('jon', True): 8,
#  ('download', True): 52,
#  ('tumb', True): 2,
#  ('pictwittercom/wav1bacr5j', False): 3,
#  ('pictwittercom', False): 283,
#  ('/', False): 2005,
#  ('wav1bacr5j', False): 2,
#  ('picwikipediaorg', False): 75,
#  ('v', False): 295,
#  ('borderlandsi', True): 47,
#  ('omg', True): 163,
#  ('ever', True): 496,
#  ('someth', False): 382,
#  ('seem', False): 231,
#  ('broken', False): 292,
#  ('m10', False): 6,
#  ('rate', False): 184,
#  ('constantli', False): 62,
#  ('less', False): 110,
#  ('lot', False): 168,
#  ('lower', False): 57,
#  ('mayhem', False): 12,
#  ('level', False): 100,
#  ('possibl', False): 109,
#  ('+2500%', False): 3,
#  ('loot', False): 62,
#  ('modifi', False): 8,
#  ('swear', False): 64,
#  ("i'm", False): 774,
#  ('see', False): 552,
#  ('green', False): 45,
#  ('blue', False): 62,
#  ('anyth', False): 213,
#  ('kill', False): 290,
#  ('fall', False): 76,
#  ('chao', False): 9,
#  ('+', False): 54,
#  ('2500%', False): 1,
#  ('+%', False): 3,
#  ('product', False): 131,
#  ('kinda', False): 89,
#  ('push', False): 49,
#  ('normal', False): 63,
#  ('peopl', False): 939,
#  ('move', False): 120,
#  ('2', False): 64,
#  ('recoveri', False): 27,
#  ('levelshow', False): 1,
#  ('fast', False): 61,
#  ('next', False): 230,
#  ('oni', False): 1,
#  ('actual', False): 455,
#  ('gold', False): 60,
#  ('amount', False): 72,
#  ('work', False): 806,
#  ('on<unk>', False): 1,
#  ('borderlandswith', True): 11,
#  ('entir', True): 76,
#  ('polycul', True): 4,
#  ('tonight', True): 204,
#  ('magic', True): 30,
#  ('end', True): 258,
#  ('*sigh*', True): 3,
#  ('allow', True): 32,
#  ('borderlandstonight', True): 1,
#  ('polyphoni', True): 1,
#  ('*', True): 80,
#  ('sigh', True): 5,
#  ('polyslic', True): 1,
#  ('better', True): 255,
#  ('partwith', True): 1,
#  ('jacksonwith', True): 1,
#  ('complet', True): 164,
#  ('happi', True): 536,
#  ('profit-wis', False): 3,
#  ('expect', False): 64,
#  ('due', False): 166,
#  ('huge', False): 100,
#  ('budget', False): 15,
#  ('profit', False): 27,
#  ('realiz', False): 58,
#  ('bust', False): 26,
#  ('-', False): 667,
#  ('wise', False): 14,
#  ('market', False): 99,
#  ('busi', False): 169,
#  ('prior', False): 1,
#  ('problem', False): 575,
#  ('far', True): 160,
#  ('borderlandswil', True): 3,
#  ('alway', True): 297,
#  ('fav', True): 43,
#  ('borderlandsnot', True): 1,
#  ('borderlandscertainli', True): 1,
#  ('<unk>i', True): 2,
#  ('guardianwil', True): 1,
#  ('around', True): 150,
#  ('borderlandsthi', True): 9,
#  ('weekend', True): 155,
#  ('alreadi', True): 255,
#  ('manag', True): 51,
#  ('done', True): 172,
#  ('launch', True): 104,
#  ('offici', True): 56,
#  ('whole', True): 109,
#  ('turn', True): 90,
#  ('night', True): 300,
#  ('heep', True): 4,
#  ("borderlandswe'r", True): 4,
#  ('closer', True): 23,
#  ('toward', True): 41,
#  ('amaz', True): 687,
#  ('streamer', True): 27,
#  ('art', True): 67,
#  ('piec', True): 66,
#  ('follow', True): 139,
#  ('goodnight', True): 14,
#  ('load', True): 49,
#  ('borderlandsw', True): 1,
#  ('clocksydraw', True): 2,
#  ('artwork', True): 5,
#  ('follow-up', True): 1,
#  ('drove', True): 1,
#  ('street', True): 20,
#  ('work', True): 581,
#  ('let', True): 210,
#  ('imit', True): 1,
#  ('do<unk>', True): 3,
#  ("borderlandswe'l", True): 1,
#  ('brilliant', True): 39,
#  ('cool', True): 368,
#  ('bl3', False): 18,
#  ('use', False): 606,
#  ('girl', False): 47,
#  ('fire', False): 90,
#  ('end', False): 191,
#  ('credit', False): 87,
#  ('i’m', False): 392,
#  ('gonna', False): 199,
#  ('quit', False): 168,
#  ('forev', False): 36,
#  ('reason', False): 283,
#  ('leav', False): 148,
#  ('remind', False): 34,
#  ('probabl', False): 196,
#  ('r', False): 66,
#  ('old', False): 203,
#  ('know', False): 674,
#  ('watch', False): 232,
#  ('yoooooooooo', True): 4,
#  ('movi', True): 108,
#  ('yooooooooooo', True): 1,
#  ('puf', True): 2,
#  ('yooooooooo', True): 1,
#  ('current', True): 126,
#  ('littl', True): 225,
#  ('bc', True): 39,
#  ('okay', True): 52,
#  ('kind', True): 67,
#  ('fine', True): 38,
#  ('countri', True): 33,
#  ('bbc:', True): 1,
#  ('year', True): 487,
#  ('region', True): 9,
#  ('think', True): 466,
#  ('next', True): 365,
#  ('borderlands:', True): 5,
#  ('handsom', True): 30,
#  ('collect', True): 58,
#  ('welcom', True): 85,
#  ('council', True): 2,
#  ('short', True): 55,
#  ('true', True): 65,
#  ('second', True): 110,
#  ("how'r", True): 1,
#  ('disagre', True): 6,
#  ('psycho', True): 22,
#  ('krieg', True): 16,
#  ('fantast', True): 112,
#  ('fustercluck', True): 10,
#  ('wonder', True): 93,
#  ('borderlandsdlc', True): 6,
#  ('line', True): 102,
#  ('focus', True): 21,
#  ('last', True): 376,
#  ('player', True): 266,
#  ('closur', True): 4,
#  ('big', True): 257,
#  ('question', True): 23,
#  ('krieg’', True): 1,
#  ('memor', True): 15,
#  ('interact', True): 29,
#  ('conclus', True): 6,
#  ('offer', True): 60,
#  ('long-last', True): 1,
#  ('issu', True): 54,
#  ('war', True): 274,
#  ('"psycho', True): 1,
#  ('ostik', True): 1,
#  ('fusterkluck"', True): 1,
#  ('perfect', True): 213,
#  ('"borderland', True): 1,
#  ('3"', True): 4,
#  ('"favorit', True): 1,
#  ('opportun', True): 35,
#  ('close', True): 88,
#  ('import', True): 68,
#  ("about'", True): 1,
#  ('sceneri', True): 8,
#  ('vs', True): 30,
#  ('primari', True): 8,
#  ('book', True): 64,
#  ('’', True): 581,
#  ('klau', True): 1,
#  ('rang', True): 4,
#  ('sever', True): 20,
#  ('hate', False): 517,
#  ('algorithm', False): 14,
#  ('alma', False): 1,
#  ('mater', False): 1,
#  ('april', True): 39,
#  ('patch', True): 66,
#  ('+', True): 82,
#  ('mini', True): 15,
#  ('difficulti', True): 23,
#  ('modifi', True): 5,
#  ('ramp', True): 4,
#  ('gear', True): 30,
#  ('stat', True): 14,
#  ('combin', True): 38,
#  ('fresh', True): 30,
#  ('extra', True): 27,
#  ('total', True): 105,
#  ('latest', True): 29,
#  ('ultim', True): 37,
#  ('onlinei', True): 1,
#  ('brand', True): 42,
#  ('level', True): 85,
#  ('power', True): 152,
#  ('up<unk>', True): 2,
#  ('appear', True): 25,
#  ('accid', True): 12,
#  ('apolog', True): 21,
#  ('back', True): 643,
#  ('idea', True): 109,
#  ('happen', True): 136,
#  ('hi', True): 48,
#  ('optu', True): 2,
#  ('seem', True): 153,
#  ('electr', True): 8,
#  ('excus', True): 20,
#  ('flow', True): 14,
#  ('land', True): 32,
#  ('oper', True): 30,
#  ('report', True): 70,
#  ('blood', True): 36,
#  ("i'", True): 7,
#  ('us', True): 303,
#  ('though', True): 123,
#  ('exactli', True): 35,
#  ('<unk>', True): 311,
#  ('review', True): 53,
#  ('hearti', True): 2,
#  ('congratul', True): 111,
#  ('famili', True): 85,
#  ('nomin', True): 9,
#  ('wooohoooo', True): 5,
#  ('playapex', True): 70,
#  ('respawn', True): 7,
#  ('callofduti', True): 23,
#  ('destinythegam', True): 6,
#  ('baftagam', True): 2,
#  ('heartfelt', True): 1,
#  ('cfduti', True): 18,
#  ('woooooooo', True): 1,
#  ('special', True): 67,
#  ('fellow', True): 3,
#  ('campaign', True): 56,
#  ('project', True): 57,
#  ('distinguish', True): 1,
#  ('put', True): 161,
#  ('numer', True): 2,
#  ('foundat', True): 3,
#  ('strong', True): 60,
#  ('my<unk>', True): 2,
#  ('parent', True): 16,
#  ('adopt', True): 1,
#  ('variou', True): 8,
#  (':y', True): 3,
#  ('pictwittercom/xr9p3ursqg', True): 3,
#  ('character:', True): 2,
#  ('xr9p3ursqg', True): 2,
#  ('picwikipediaorg', True): 69,
#  ('myfav', True): 2,
#  ('minecraft', True): 20,
#  ('2forza', True): 5,
#  ('horizonlego', True): 4,
#  ('star', True): 112,
#  ('myfavorit', True): 3,
#  ('h4', True): 2,
#  ('lego', True): 13,
#  ('tournamentlego', True): 1,
#  ('2', True): 92,
#  ('favouritefav', True): 1,
#  ('epth', True): 1,
#  ('forza', True): 7,
#  ('screenfav', True): 1,
#  ('titl', True): 17,
#  ('4', True): 48,
#  ('accomplish', True): 10,
#  ('realiti', True): 19,
#  ('suffer', True): 7,
#  ('die', True): 116,
#  ('achiev', True): 72,
#  ('spill', True): 1,
#  ('fact', True): 82,
#  ('seemingli', True): 3,
#  ('hey', False): 343,
#  ('access', False): 255,
#  ('mission', False): 76,
#  ('noth', False): 306,
#  ('epic', False): 85,
#  ('put', False): 243,
#  ('focu', False): 22,
#  ('u', False): 408,
#  ('consol', False): 244,
#  ('four', False): 53,
#  ('still', False): 1036,
#  ('quickli', False): 37,
#  ('hit', False): 141,
#  ('play', False): 2019,
#  ('open', False): 306,
#  ('samsung', True): 24,
#  ('full', True): 77,
#  ('homework', True): 12,
#  ('away', True): 78,
#  ('ps4', True): 106,
#  ('fort', True): 11,
#  ('havew', True): 5,
#  ('overwatch', True): 416,
#  ('junkratt', True): 4,
#  ("that'", True): 191,
#  ('continu', True): 79,
#  ('frontier', True): 15,
#  ('commut', True): 2,
#  ("he'", True): 28,
#  ('home', True): 486,
#  ('affair', True): 1,
#  ('f4', True): 1,
#  ('want', True): 595,
#  ('jratt', True): 1,
#  ('paid', True): 13,
#  ('thewant', True): 1,
#  ('said', True): 106,
#  ('phone', True): 90,
#  ("has't", True): 1,
#  ('month', True): 227,
#  ('pleas', True): 286,
#  ('tell', True): 141,
#  ('ascens', True): 5,
#  ('bluff', True): 12,
#  ('door', True): 17,
#  ('may', True): 107,
#  ('extrem', True): 50,
#  ("isit'", True): 1,
#  ('prepar', True): 13,
#  ('base', True): 61,
#  ('station', True): 16,
#  ("doorit'", True): 1,
#  ('months<unk>', True): 1,
#  ('cast', True): 32,
#  ('lilith', True): 15,
#  ('anticip', True): 17,
#  ('film', True): 56,
#  ('"lilit"', True): 1,
#  ('borderlandsachiev', False): 5,
#  ('unreal', False): 34,
#  ('guy', False): 682,
#  ('figur', False): 72,
#  ('gearboxoffici', False): 20,
#  ('achiev', False): 19,
#  ("borderlandsit'", False): 1,
#  ('understand', False): 130,
#  ('dont', False): 236,
#  ('com', False): 139,
#  ('bad', False): 677,
#  ('check', False): 125,
#  ('love(d)', False): 3,
#  ("i'v", False): 379,
#  ('spent', False): 80,
#  ('325hr', False): 5,
#  ('beat', False): 62,
#  ('twice', False): 96,
#  ('crazi', False): 187,
#  ('weapon', False): 65,
#  ('anoint', False): 9,
#  ('want', False): 678,
#  ('decid', False): 113,
#  ('way', False): 346,
#  ('intend', False): 7,
#  ('weaken', False): 5,
#  ('favorit', False): 53,
#  ('love', False): 328,
#  ('(d)', False): 2,
#  ('spenthour', False): 1,
#  ('ointment', False): 1,
#  ('album', False): 8,
#  ('money', False): 473,
#  ('discov', False): 18,
#  ('one', False): 1011,
#  ('absolut', False): 240,
#  ('(', False): 147,
#  (')', False): 97,
#  ("i'w", False): 1,
#  ('total', False): 139,
#  ("but'v", False): 1,
#  ('say', False): 672,
#  ('gay', True): 21,
#  ('wed', True): 7,
#  ('borderlandsfeel', True): 2,
#  ('rn', True): 31,
#  ('celebr', True): 39,
#  ('wwe', True): 2,
#  ('episodefeel', True): 1,
#  ('borderlandsa', True): 2,
#  ('pictwittercom/pkzjxlgxlj', True): 3,
#  ('duvalmag', True): 8,
#  ('gearboxoffici', True): 9,
#  ('pkzjxlgxlj', True): 2,
#  ('catch', True): 10,
#  ('picfm', True): 38,
#  ('f', True): 26,
#  ('lil', True): 22,
#  ('preview', True): 24,
#  ('draw', True): 43,
#  ('chip', True): 4,
#  ('sink', True): 4,
#  ('late', True): 124,
#  ('pictwittercom/1nye0s5cm', True): 3,
#  ('mayan', True): 1,
#  ('spend', True): 70,
#  ('spare', True): 2,
#  ('1nye0s5cm', True): 2,
#  ('chime', True): 1,
#  ('picfacebookcom', True): 71,
#  ('c', True): 32,
#  ('u', True): 228,
#  ('borderlandspretti', True): 5,
#  ('imo', True): 21,
#  ('anyway', True): 79,
#  ('whatev', True): 36,
#  ('pictwittercom/uoute82ado', True): 3,
#  ('uoute82ado', True): 2,
#  ('whatsoev', True): 2,
#  ('tv', True): 65,
#  ('3:', True): 12,
#  ('tentacl', True): 17,
#  ('hear', True): 78,
#  ('voic', True): 36,
#  ('half', True): 58,
#  ('youtub', True): 236,
#  ('channel', True): 29,
#  ('hell', True): 119,
#  ('yeah', True): 92,
#  ('forev', True): 57,
#  ('apart', True): 26,
#  ('creepi', True): 6,
#  ('ass', True): 108,
#  ('gamegrump', True): 1,
#  ('egoraptor', True): 1,
#  ('separ', True): 6,
#  ('gamegrup', True): 1,
#  ('lose', True): 81,
#  ('cartoon', True): 1,
#  ('season:', True): 1,
#  ('later', True): 79,
#  ('old', True): 178,
#  ('music', True): 143,
#  ('demon', True): 34,
#  ('doesnt', True): 12,
#  ('pictwittercom/x3dyptnald', True): 3,
#  ('smilingocean', True): 2,
#  ('x3dyptnald', True): 2,
#  ('picit', True): 2,
#  ('n', True): 46,
#  ('despis', False): 22,
#  ('area', False): 47,
#  ('borderlandsi', False): 9,
#  ('rust', False): 10,
#  ('common', False): 26,
#  ('mani', False): 376,
#  ('sidequest', False): 3,
#  ('favourit', False): 15,
#  ('borderlandsright', False): 1,
#  ('sidewalk', False): 1,
#  ('great', False): 252,
#  ('2007', False): 1,
#  ('land', False): 20,
#  ('left', False): 107,
#  ('lee', False): 2,
#  ('block', False): 109,
#  ('kensington', False): 1,
#  ('holi', False): 118,
#  ('week', False): 177,
#  ('sick', False): 112,
#  ("we'v", True): 41,
#  ('borderlandson', True): 24,
#  ('gotta', True): 64,
#  ('stun', True): 41,
#  ('cosplay', True): 16,
#  ('kunaii', True): 5,
#  ('instagramcom/xxkunaiixx/', True): 3,
#  ('borderlandsalso', True): 1,
#  ('must', True): 79,
#  ('instagramcom', True): 7,
#  ('xxkunaiixx', True): 2,
#  ('https:', True): 110,
#  ('tco', True): 83,
#  ('giwx2aqtuy', True): 2,
#  ('global', True): 32,
#  ('xxxaiiicom', True): 1,
#  ('fenco', True): 12,
#  ('save', True): 90,
#  ('monkey', True): 2,
#  ('fox', True): 28,
#  ('usingtrack', True): 1,
#  ('x', True): 347,
#  ('read', True): 66,
#  ('instagram', True): 5,
#  ('com', True): 155,
#  (']', True): 82,
#  ('blast', True): 25,
#  ('face', True): 85,
#  ('•', True): 25,
#  ('jackson', True): 15,
#  ('gearbox', True): 11,
#  ('you’v', True): 4,
#  ('crush', True): 32,
#  ('enven', True): 4,
#  ('covid', True): 24,
#  ('difficult', True): 21,
#  ('broken', True): 36,
#  ('…', True): 146,
#  ('wheel', True): 3,
#  ('understand', True): 57,
#  ('excit', True): 719,
#  ('excel', True): 99,
#  ('proton-m', True): 1,
#  ('vehicl', True): 28,
#  ('disappear', True): 16,
#  ('certainli', True): 44,
#  ('develop', True): 63,
#  ('cours', True): 46,
#  ('glad', True): 138,
#  ('effort', True): 24,
#  ('noticed;', True): 5,
#  ('4-way', True): 5,
#  ('co-op', True): 10,
#  ('pictwittercom/vcgncpmavu', True): 3,
#  ('unitedhayz', True): 2,
#  ('vcgncpmavu', True): 2,
#  ('2014', True): 8,
#  ('super', True): 268,
#  ('tempt', True): 9,
#  ('simpl', True): 38,
#  ('black', True): 334,
#  ('heart', True): 91,
#  ('tattoo', True): 20,
#  ('right', True): 361,
#  ('tit', True): 4,
#  ('elli', True): 11,
#  ('lol', True): 236,
#  ('idk', True): 32,
#  ("i'd", True): 33,
#  ('thought', True): 98,
#  ('small', True): 86,
#  ('pool', True): 29,
#  ('peopl', True): 494,
#  ('didcaus', True): 3,
#  ('common', True): 8,
#  ('temptat', True): 1,
#  ('quit', True): 124,
#  ('shoulder', True): 1,
#  ('borderlandsidk', True): 1,
#  ('id', True): 22,
#  ('caus', True): 98,
#  ('soul', True): 28,
#  ('white', True): 33,
#  ('local', True): 18,
#  ('borderlandssuch', True): 4,
#  ('playerssuch', True): 1,
#  ('4player', True): 1,
#  ('shop', True): 34,
#  ('sli', True): 6,
#  ('haha', True): 19,
#  ('mission', True): 49,
#  ('“the', True): 5,
#  ('dark”', True): 2,
#  ('mine', True): 32,
#  ('moria', True): 6,
#  ('"the', True): 26,
#  ('dark"', True): 2,
#  ('g', True): 21,
#  ('“', True): 38,
#  ('high', True): 76,
#  ('district', True): 8,
#  ('dark', True): 39,
#  ('”', True): 27,
#  ('key', True): 25,
#  ('jar', True): 1,
#  ('del', True): 2,
#  ('xbox', True): 548,
#  ('dope', True): 136,
#  ('tryna', True): 26,
#  ('squad', True): 54,
#  ('mann', True): 4,
#  ('man', True): 260,
#  ('trina', True): 3,
#  ('shit', True): 398,
#  ('buy', True): 355,
#  ('forxbox', True): 2,
#  ('borderlandsmight', True): 4,
#  ('5th', True): 5,
#  ('fave', True): 35,
#  ...}

# %%
V = []

for word in freqs:
    V.append(word[0])
    
V_set = set(V)

# %%
len(V_set)
# Out:
# 25636

# %%
N_pos=0
N_neg =0

for word in freqs:
    if word[1]:
        N_pos += freqs[word]
    else:
        N_neg += freqs[word]

# %%
N_neg,N_pos
# Out:
# (245078, 201079)

# %%
cond_prob = {}

for word in V_set:
    w1 = (freqs.get((word,True),0) +1) / (N_pos + len(V_set))
    w2 = (freqs.get((word,False),0) +1) / (N_neg + len(V_set))
    ratio = w1 / w2
    log_likelihood = math.log(ratio)
    cond_prob[word] = log_likelihood

# %%
cond_prob
# Out:
# {'h5': -0.5157779895730061,
#  '"shit"': -0.5157779895730061,
#  'redemptionsound': 1.969128660214994,
#  'going-0': -0.5157779895730061,
#  'buynot': -0.5157779895730061,
#  'burden': -0.738921540887216,
#  'cipher': 1.7868071034210395,
#  'month:new': 1.2759814796550488,
#  'babe': -1.9020723506928967,
#  'pictwittercom/izoafew163': -1.2089251701329515,
#  'yourdemo': -0.5157779895730061,
#  'pictwittercom/gfk7wn5bow': -1.2089251701329515,
#  'facebook-remov': -0.5157779895730061,
#  'playstationupd': 0.8705163715468844,
#  'kati': 0.023218511159680853,
#  'technique:': 0.8705163715468844,
#  "lincoln'": -0.5157779895730061,
#  'fortim': 0.8705163715468844,
#  'pictwittercom/axjqc4pift': -1.2089251701329515,
#  'pictwittercom/mcgptlss5': 1.5636635521068298,
#  'theto': -1.614390278241116,
#  'inwould': -1.4320687214471612,
#  'lack': -1.4540476281659365,
#  'handsom': 1.8195969262440304,
#  'highmountain': 1.969128660214994,
#  'titanfalldo': -0.5157779895730061,
#  '4-inch': 0.8705163715468844,
#  'careless': -0.5157779895730061,
#  'syndic': 1.3225014952899417,
#  'runsavag': 0.8705163715468844,
#  'thenyou': -1.4320687214471612,
#  'blindli': -0.9212430976811705,
#  '🥖': 1.2759814796550488,
#  'godwork': 0.8705163715468844,
#  'fgplmast8': 0.8705163715468844,
#  'shark': 0.7369849789223617,
#  'llm': 0.8705163715468844,
#  'probl': -1.2089251701329515,
#  '1:am': -0.9212430976811705,
#  'gaga': -1.768540958068374,
#  'gtafreez': -0.5157779895730061,
#  'tool': 2.1514502170089487,
#  'hypedd': 1.7868071034210395,
#  'rdr2': 0.17736919098693915,
#  'wildli': -1.768540958068374,
#  '763on': -0.5157779895730061,
#  'nw1lmrjgn6': -0.5157779895730061,
#  'beauti': 2.678174426842738,
#  'zombie<unk>': 0.8705163715468844,
#  'd04gqso6kg': 0.8705163715468844,
#  "didn'at": -0.5157779895730061,
#  'admit': -1.4808588856165932,
#  "in't": 0.8705163715468844,
#  'hatr': -1.527378901251486,
#  'boil': -0.9212430976811705,
#  'youtube/kwvoxuu0-t0': 1.5636635521068298,
#  'fb': -1.8470125735098695,
#  'ago': -0.1347639773290062,
#  "remake'": -0.9212430976811705,
#  'wanna': 0.37152520542789647,
#  'cookenboy1794': -0.9212430976811705,
#  'gearhd': 0.8705163715468844,
#  'pontenti': 1.969128660214994,
#  "'verizon": 0.8705163715468844,
#  'season:': 0.8705163715468844,
#  'roshantim': 1.969128660214994,
#  'saying:': -0.9212430976811705,
#  'homo': 0.35969074778089355,
#  'takes:': -1.2089251701329515,
#  '2kass': -1.2089251701329515,
#  'hashtag': -2.307537458801061,
#  'nadella': 1.969128660214994,
#  'nflfeel': -1.614390278241116,
#  'an0': -0.5157779895730061,
#  'akem9uwz2q': 1.2759814796550488,
#  'grounds"': -1.4320687214471612,
#  'hawthorn': 0.8705163715468844,
#  "rhandlerr'": 1.2759814796550488,
#  'watchedmin': 1.7868071034210395,
#  'jan': -1.2089251701329515,
#  'fume': -1.2089251701329515,
#  'later*': -0.9212430976811705,
#  'sri': -1.768540958068374,
#  'patch': -0.7596017461247546,
#  'land': 0.6293543147299963,
#  'yorkregiongoo': -0.5157779895730061,
#  "'queen": 1.5636635521068298,
#  'afp': -0.9212430976811705,
#  'finallyand': 1.5636635521068298,
#  "samuel'": 0.8705163715468844,
#  'bitcoin': 2.5752644637853095,
#  'room-': -0.5157779895730061,
#  'openingh': -0.9212430976811705,
#  '"right': 1.2759814796550488,
#  'ident': -0.8034600620247873,
#  'redeemingto': 0.8705163715468844,
#  '&<unk>': 0.5828342990951034,
#  'lightn': 0.31090058361146194,
#  'warcraftto': -1.4320687214471612,
#  'gladiat': -0.5157779895730061,
#  'weak': -1.075393777508429,
#  'anz': 0.17736919098693915,
#  'collis': 0.8705163715468844,
#  'arena': 0.23143641225721487,
#  '|dadaabhihai': 0.8705163715468844,
#  'fault': -0.39799495391662276,
#  'toddler': -1.768540958068374,
#  'andminut': 2.742318548448476,
#  'einar': 1.5636635521068298,
#  'loadsclick': -1.2089251701329515,
#  'rbellcrow': -0.5157779895730061,
#  'eg': -0.5157779895730061,
#  'foxnewscom': -0.9212430976811705,
#  'danielth': 0.8705163715468844,
#  'priest': 0.5630316717989239,
#  'agro': -0.5157779895730061,
#  'toprun': -0.5157779895730061,
#  'plug': 0.6473728202326747,
#  'electronicart': 0.8705163715468844,
#  'monolith': 1.969128660214994,
#  'opinion': 0.32397266517881446,
#  'hundr': -0.0804599183151606,
#  'pictwittercom/tvwfllkjk': -1.2089251701329515,
#  'fiction': 0.5138414276081519,
#  'thoughts:': -0.5157779895730061,
#  'todaysab': 0.8705163715468844,
#  'phone/internet/c': 1.5636635521068298,
#  'cyber-attacks:': 1.5636635521068298,
#  '32k': 1.969128660214994,
#  'miyamotogam': 0.8705163715468844,
#  'go6ngetovd': 1.2759814796550488,
#  'pnxq0bohtr': 0.8705163715468844,
#  'hadfoul': -1.614390278241116,
#  '$85': 1.969128660214994,
#  'composit': 0.8705163715468844,
#  'role-play': 1.969128660214994,
#  'pmnvus0': 0.8705163715468844,
#  'potenti': -0.33345643277905157,
#  'atroc': -1.768540958068374,
#  'poggermoment:': 0.8705163715468844,
#  'success': 0.27089524899776246,
#  'ukgooglehitscom': -0.5157779895730061,
#  'polish': -0.22809591712122537,
#  'ddo': -1.614390278241116,
#  "infants'tylenol": -0.5157779895730061,
#  'omgggg': -0.9212430976811705,
#  'relax': 0.37803988644909026,
#  '"old': 0.8705163715468844,
#  'bennitestatu': -0.5157779895730061,
#  'essay': 2.1232793400422523,
#  'soulsunchartedunchartedsup': 0.8705163715468844,
#  'tuba': 2.1232793400422523,
#  'tofrompleas': -0.5157779895730061,
#  '"get': 0.35969074778089355,
#  'challen': -0.5157779895730061,
#  '36': 0.17736919098693915,
#  'pictwittercom/d52pxtqhdd': 1.5636635521068298,
#  '•pay': 1.5636635521068298,
#  'ordzokcb3oa': -0.9212430976811705,
#  'marksgreat': -0.5157779895730061,
#  'youtube/u1f2j4myjuw': 1.2759814796550488,
#  'aphelio': -1.9020723506928967,
#  '72': 0.8705163715468844,
#  'streamlab': 1.5636635521068298,
#  '3/4': 0.8705163715468844,
#  'pictwittercom/u2xl9gpd2u': -1.2089251701329515,
#  'wellb': 0.8705163715468844,
#  'lube': 1.5636635521068298,
#  'adopt': -0.22809591712122523,
#  'leve': -0.9212430976811705,
#  'tape': -0.9212430976811705,
#  'ddq8wexjl': -0.9212430976811705,
#  'restart': -1.4420190523003293,
#  'tasmania-poppi': -0.5157779895730061,
#  'andgam': 2.1232793400422523,
#  'battlefieldlibel': -0.5157779895730061,
#  'gollf': -0.5157779895730061,
#  'tumor': -0.9212430976811705,
#  'fixed%': 0.8705163715468844,
#  'jack': 2.0491713678885306,
#  'amper': 1.969128660214994,
#  'weekend': 1.730717636769996,
#  'addict': 0.38370562398476765,
#  'kennit': 0.8705163715468844,
#  'badmi': -0.5157779895730061,
#  'hedyoake7': -0.5157779895730061,
#  'marri': 1.8821172832253643,
#  'youtube/rteunyyvju0': 0.8705163715468844,
#  '10xx': -0.5157779895730061,
#  'replac': -0.8034600620247873,
#  'da2': -1.4320687214471612,
#  'strang': 0.8705163715468844,
#  'pictwittercom/fb2yghdve2': -1.2089251701329515,
#  'pictwittercom/vhd6thlp16': -1.2089251701329515,
#  '-ban': -1.614390278241116,
#  'pictwittercom/lz3tfwsu4': -1.2089251701329515,
#  'ventur': -0.9212430976811705,
#  'bluntit': -0.5157779895730061,
#  'dual': 0.5340441349256715,
#  'creepi': 0.04383779836241637,
#  'greenamorg': -0.9212430976811705,
#  '=packersand': -0.5157779895730061,
#  'everyminut': -0.9212430976811705,
#  'buck': 0.7651558558890582,
#  '"no': -0.9212430976811705,
#  'pictwittercom/a2rwumwaga': 1.5636635521068298,
#  'kevindglov': 0.8705163715468844,
#  'chief:': 1.969128660214994,
#  'yesslow': -0.5157779895730061,
#  'terror"': -0.9212430976811705,
#  'can<unk>': -0.5157779895730061,
#  '"ye': -0.9212430976811705,
#  'here--': 0.8705163715468844,
#  'babl': -0.5157779895730061,
#  'nba2k20': -2.530681010115271,
#  'observ': 0.17736919098693915,
#  '"soon"': -1.614390278241116,
#  'shrill': -0.5157779895730061,
#  '$atvi': 1.7868071034210395,
#  'ice': 0.0863974127812125,
#  '"it\'': 0.5828342990951034,
#  'verizon-mobil': -0.5157779895730061,
#  'ps5"': 0.8705163715468844,
#  'alter': 0.17736919098693915,
#  '40': -1.614390278241116,
#  'regular': 0.482750840538121,
#  'dgonsssssss': 0.8705163715468844,
#  ':william': 0.8705163715468844,
#  'popularity:visa': 0.8705163715468844,
#  '-5384386010/': -0.9212430976811705,
#  'gotsec': -0.5157779895730061,
#  'cthulhu:': -0.5157779895730061,
#  'lwtf': -0.5157779895730061,
#  'muscl': -0.9212430976811705,
#  'roommat': -1.768540958068374,
#  'nfl[': -0.5157779895730061,
#  'econom': 0.17736919098693915,
#  "'preset'": -1.4320687214471612,
#  'hero<unk>': 0.8705163715468844,
#  'bbb': -0.9212430976811705,
#  'howard': -2.2205260818114314,
#  'april': 1.920338496045562,
#  'gossip': 0.8705163715468844,
#  'youtube/cntgvpcnabw': 1.2759814796550488,
#  'do<unk>': 0.17736919098693915,
#  '416-c': 1.7868071034210395,
#  'colat': 2.1232793400422523,
#  'austinef': -1.2089251701329515,
#  'grade': -1.768540958068374,
#  'slur': -1.614390278241116,
#  'sinceget': -1.4320687214471612,
#  '¨': -0.5157779895730061,
#  '(earli': 1.7868071034210395,
#  ':controversi': -0.5157779895730061,
#  'pwarx3': 1.2759814796550488,
#  'hour:01:': 0.8705163715468844,
#  'onmonths&': -0.5157779895730061,
#  'battlefront': 1.969128660214994,
#  'tammyrheemwat': 1.2759814796550488,
#  'pinch': 1.0936599228610941,
#  'derrick': 2.1232793400422523,
#  'ykoqagelo': -0.9212430976811705,
#  'trauma': -1.9020723506928967,
#  'worthdollar': -0.5157779895730061,
#  'overwork': -0.9212430976811705,
#  'do-it-yourself': -0.5157779895730061,
#  'undecid': -0.5157779895730061,
#  "freakin'y": 0.8705163715468844,
#  "demon'": -1.4320687214471612,
#  'facebook-d': -0.5157779895730061,
#  'dynamicsc': -1.2089251701329515,
#  'irritatingli': -0.5157779895730061,
#  'cancer-caus': -1.9020723506928967,
#  'pictwittercom/psdtzfzliv': -1.2089251701329515,
#  'threatened<unk>': -0.5157779895730061,
#  'teamer': 1.7868071034210395,
#  '"eh': 1.969128660214994,
#  'smbnjk2z3j': -0.9212430976811705,
#  '“huh': 1.2759814796550488,
#  'mann': 0.40051274230114886,
#  'rx': 1.2759814796550488,
#  'respecth': 0.8705163715468844,
#  "borderlandsi'l": 1.7868071034210395,
#  '$ine': -1.2089251701329515,
#  'ericgharrison': 1.2759814796550488,
#  '11/10': 1.5636635521068298,
#  'ruf': -0.5157779895730061,
#  'test': -0.12740731482414186,
#  'promo': -2.818363082567052,
#  '<unk>-you': 0.8705163715468844,
#  'taken:': -1.4320687214471612,
#  'young': 1.4766521751172,
#  'complete<unk>': -0.5157779895730061,
#  "there'r": 1.2759814796550488,
#  'onlyconsol': 0.8705163715468844,
#  'allspe': -0.5157779895730061,
#  'ratchet': 0.35969074778089355,
#  'regga': 0.8705163715468844,
#  'metropoli': 0.8705163715468844,
#  'rumbl': -0.5157779895730061,
#  'deadi': 0.17736919098693915,
#  '3ghluy7': 1.5636635521068298,
#  'job"': 0.8705163715468844,
#  'useem': 0.8705163715468844,
#  'fascin': 3.067740948883104,
#  'robinhought': 1.2759814796550488,
#  'kelly"': -0.5157779895730061,
#  'jackpot': 1.2759814796550488,
#  'blatant': -2.655844153069277,
#  'vac': -0.44167001741928447,
#  'more(spread': 1.2759814796550488,
#  'nxdb0i8ye7': -0.9212430976811705,
#  'unrespons': -0.5157779895730061,
#  'thatcan': -0.5157779895730061,
#  'fk': 0.17736919098693915,
#  "loba'": 0.8705163715468844,
#  'lubric': 0.8705163715468844,
#  'woooooo': 1.5636635521068298,
#  'uoute82ado': 1.2759814796550488,
#  '“aim': -1.2089251701329515,
#  'kalloori': 1.7868071034210395,
#  'postinghim': -1.4320687214471612,
#  'where&scam': -0.5157779895730061,
#  'revolutionari': -0.22809591712122523,
#  'pictwittercom/0kxwxlkxvl': -1.2089251701329515,
#  'nier:automatapokemon': -0.5157779895730061,
#  'wyf': -1.614390278241116,
#  'bape”': -1.2089251701329515,
#  'assyear': -0.5157779895730061,
#  '"termin': 1.0936599228610941,
#  'jumjzheik': 1.2759814796550488,
#  'compute-intens': 1.7868071034210395,
#  'oahu53': -0.5157779895730061,
#  'nviia': 0.8705163715468844,
#  'youtubecom/watchv=bbb8oz…': 1.2759814796550488,
#  'anotheryear': 1.969128660214994,
#  'allen"': -0.9212430976811705,
#  'wack': -0.738921540887216,
#  'repres': -0.40244930426600317,
#  'justminut': 0.8705163715468844,
#  '20%': 1.7868071034210395,
#  "mornin'": -1.2089251701329515,
#  'redemptiontattoo': 1.969128660214994,
#  'draw': 1.5636635521068298,
#  'cove': 2.1232793400422523,
#  'mxsd3hat': 0.8705163715468844,
#  'furi': -0.5157779895730061,
#  "has't": 0.8705163715468844,
#  'frick': -0.023301504475211943,
#  'nowher': -1.6944329859146523,
#  'hashtagguysin': -0.5157779895730061,
#  "janssen'": 1.7868071034210395,
#  'forgig': -2.0198553863492803,
#  'seen;': 0.8705163715468844,
#  'mistyapathet': -0.9212430976811705,
#  'gamegrup': 0.8705163715468844,
#  'facemask': -1.4320687214471612,
#  'panther': 0.8705163715468844,
#  'beth': 1.430132159482307,
#  '"turalion"': 0.8705163715468844,
#  'nvidialinux': -0.5157779895730061,
#  '4io9': -1.2089251701329515,
#  'cooki': -0.22809591712122523,
#  'wnnr/gblqnt': 2.1232793400422523,
#  'midfield': -1.768540958068374,
#  'me/mi': -0.5157779895730061,
#  'rli': 0.7651558558890582,
#  'anything:': 1.7868071034210395,
#  'nysl': -1.768540958068374,
#  'twat': -1.2089251701329515,
#  'ammunit': -0.9212430976811705,
#  'mevc': -0.5157779895730061,
#  'would<unk>': 0.17736919098693915,
#  'date': -1.4548833992133328,
#  'gittin': 0.8705163715468844,
#  'junkheap': 1.969128660214994,
#  'cyberpunk': 1.0818254652140915,
#  'jacqful': 1.2759814796550488,
#  'wrsolin': -1.2089251701329515,
#  '"good': 0.8705163715468844,
#  'cryr6': -1.614390278241116,
#  'respect': 0.8354250517356142,
#  'moron': -0.6876282464996655,
#  'dotawhich': 0.8705163715468844,
#  'piec': 0.37472862514543437,
#  'convict': -0.9212430976811705,
#  "1988'": 0.8705163715468844,
#  'gerat': 0.8705163715468844,
#  'forlong': -0.5157779895730061,
#  'не': -0.5157779895730061,
#  'two-day': 0.5828342990951034,
#  'pictwittercom/twkakwy8ab': -1.2089251701329515,
#  'cfo': -0.5157779895730061,
#  '202': 0.17736919098693915,
#  'fatal': 2.1232793400422523,
#  '(love': 2.3745937683231584,
#  'went': -0.26930618576788823,
#  'hate;': 1.969128660214994,
#  'it🥺': 1.2759814796550488,
#  'final': 1.361018522340961,
#  'o9ebljff7m': 1.2759814796550488,
#  '“confess': 1.5636635521068298,
#  'genr': 2.605117426934991,
#  'payfor': -0.9212430976811705,
#  'spacea': 0.8705163715468844,
#  'backaus': -0.5157779895730061,
#  'scent': 0.8705163715468844,
#  'jean': -0.8034600620247873,
#  'brand-marketin': 1.2759814796550488,
#  'jeb': -0.9212430976811705,
#  'pursu': 0.4650512634387201,
#  'floati': -1.4320687214471612,
#  'c<unk>': -0.5157779895730061,
#  'warcraftlan': 1.7868071034210395,
#  'fondli': 1.969128660214994,
#  'conspiracyorg/facebook/bombs…': -0.5157779895730061,
#  'playstat': -0.0028926328440050508,
#  'wtaf': -2.2205260818114314,
#  'oralon': -0.5157779895730061,
#  'idea': -0.3796458152484263,
#  'usd': -0.22809591712122523,
#  'turnaround': 1.2759814796550488,
#  'bose': 1.2759814796550488,
#  'pictwittercom/izcv36m6xb': -1.2089251701329515,
#  'cheater': -2.0843939074868514,
#  '-thi': 1.5636635521068298,
#  'hotfix': -2.2205260818114314,
#  'shelv': -1.0753937775084286,
#  'ad': -0.3696853710755103,
#  'bluntly:': 0.8705163715468844,
#  'bummer': 0.17736919098693915,
#  'spotifyuk': -0.9212430976811705,
#  'la42356652': 0.8705163715468844,
#  '_rghbm': -0.5157779895730061,
#  'trampl': -0.5157779895730061,
#  'exact': -1.0911421344765682,
#  '"googl': -0.9212430976811705,
#  'ethicon': -1.4320687214471612,
#  'threehazbin': 0.8705163715468844,
#  'overclock': -0.9212430976811705,
#  'successfulassassin’': -0.5157779895730061,
#  'rashford': -1.614390278241116,
#  'ester': 1.969128660214994,
#  'ipod': 0.8705163715468844,
#  '2bcproduct': 1.2759814796550488,
#  'procrastin': 1.969128660214994,
#  'but': -1.614390278241116,
#  'for“empathy2”:': 1.2759814796550488,
#  'newslett': -1.768540958068374,
#  'onlymonth': 1.0936599228610941,
#  'guin': 0.8705163715468844,
#  'bubbl': 2.1232793400422523,
#  'announcements"': 1.2759814796550488,
#  'ribbon': -1.9020723506928967,
#  'mack': -1.614390278241116,
#  'pictwittercom/wyubuf0fih': 1.5636635521068298,
#  "opponents'": -1.2089251701329515,
#  'panay': -0.9212430976811705,
#  'tier1': 1.7868071034210395,
#  'oddsbi': 1.5636635521068298,
#  'esgskv': 1.2759814796550488,
#  'forehead': -0.9212430976811705,
#  'knvb': 0.8705163715468844,
#  'aton': 0.8705163715468844,
#  'vibrant': 0.8705163715468844,
#  'u1f2j4myjuw': 1.5636635521068298,
#  'andcancel': -1.614390278241116,
#  'pbgee3i4em': 1.2759814796550488,
#  'mfacebookcom': 1.2759814796550488,
#  'mad': -0.05116520896214716,
#  'edward': 2.256810732666775,
#  'are<unk>': -0.5157779895730061,
#  'first-quart': 1.7868071034210395,
#  'robodanj': -0.9212430976811705,
#  'thing<unk>': 0.8705163715468844,
#  'queen-': 0.8705163715468844,
#  'anythingi': -0.9212430976811705,
#  'insant': 0.8705163715468844,
#  'semi': -0.5157779895730061,
#  'siren': 0.8705163715468844,
#  'what-real-w': -0.5157779895730061,
#  'cyberpunkgetsmonth': -0.5157779895730061,
#  '8am': -0.5157779895730061,
#  '(ttwo)': 1.7868071034210395,
#  'itif': -0.5157779895730061,
#  'metal': 0.5340441349256715,
#  'cylind': -0.5157779895730061,
#  'draft': -0.5958206972465427,
#  'incent': 1.969128660214994,
#  'connected=hack': -1.2089251701329515,
#  'capacitor': -1.768540958068374,
#  'shoulder': -1.3267082057893347,
#  'duellll': 1.5636635521068298,
#  'updatethat': -0.5157779895730061,
#  'communist': -1.768540958068374,
#  '<unk>be/ovnd32ezrcu': -0.5157779895730061,
#  'max3969mah': -0.5157779895730061,
#  'avg': 2.1232793400422523,
#  'sincestar': -0.5157779895730061,
#  'paper': -0.023301504475211943,
#  'anyon': -0.35797099854263736,
#  'suppli': 0.34442327565010544,
#  'thinkin': -1.614390278241116,
#  'gtamak': 1.5636635521068298,
#  'battlefieldth': 0.5828342990951034,
#  'tens': 2.1232793400422523,
#  "i'weren": 0.8705163715468844,
#  'almost': -0.3398873231093421,
#  'emhgjmh87k': 1.2759814796550488,
#  'redemptioni': 1.839916928734988,
#  'concept/plot': 1.5636635521068298,
#  'woltk': 1.969128660214994,
#  'brilliant': 1.5636635521068298,
#  'pictwittercom/hfpkpdrrq0': -1.2089251701329515,
#  'holy<unk>': 0.8705163715468844,
#  '(xbox': 2.4799542839809847,
#  'dunn': -0.5157779895730061,
#  'legends-': 1.2759814796550488,
#  'bungi': 1.969128660214994,
#  'hartston': 1.2759814796550488,
#  'rockstara': 0.8705163715468844,
#  'pawesasko': 1.2759814796550488,
#  'd54cfxhdnc': -0.5157779895730061,
#  'youtube/djj9vzkvdmw': 1.5636635521068298,
#  'foreveri': -0.5157779895730061,
#  '(montreal': -1.614390278241116,
#  'onlinei': 0.8705163715468844,
#  'regim': -0.22809591712122523,
#  'nightmarish': -0.5157779895730061,
#  'antic': 1.969128660214994,
#  'longggg': 0.8705163715468844,
#  'pictwittercom/4polxzc2d6': -1.2089251701329515,
#  'unsatisfi': 0.8705163715468844,
#  'discord': -0.45861957573305756,
#  'ridicul': -2.3011065684707708,
#  'tjwatt': -0.9212430976811705,
#  'unplay': -2.793045274582762,
#  'malfit': 0.8705163715468844,
#  'vigor': -1.4320687214471612,
#  'pizza🤦\u200d': -0.9212430976811705,
#  '(especi': -0.33345643277905174,
#  'battler': -0.5157779895730061,
#  'spacebar': -0.5157779895730061,
#  '"smart': 1.969128660214994,
#  'top(1340': -1.2089251701329515,
#  'rope': -2.1252159020071066,
#  'theflow0': 1.2759814796550488,
#  'takeagain': -0.5157779895730061,
#  'forbusi': -1.2089251701329515,
#  'song:': 0.8705163715468844,
#  'launchcurr': 0.8705163715468844,
#  'ac-styl': 0.8705163715468844,
#  'leastcalendar': -0.5157779895730061,
#  'ronal2k': -1.2089251701329515,
#  'wapost': -0.9212430976811705,
#  'aktuellnew': 0.8705163715468844,
#  'transmit': 0.8705163715468844,
#  'edgei': 0.8705163715468844,
#  '(wow)freshli': 0.8705163715468844,
#  'topwith': -0.5157779895730061,
#  'regen': -1.4320687214471612,
#  '"must': -1.614390278241116,
#  '[/': 0.17736919098693915,
#  'amazingthey': 0.8705163715468844,
#  'likecan’t': -0.5157779895730061,
#  'crumb': 1.7868071034210395,
#  'member': 0.5694112787629627,
#  'that<unk>': -0.5157779895730061,
#  'closet': -1.768540958068374,
#  'week<unk>': -0.5157779895730061,
#  'bansapp': -1.4320687214471612,
#  'certif': 0.17736919098693915,
#  'inminut': -0.030270173791305373,
#  'thetatv': 1.2759814796550488,
#  'opinion:': -1.614390278241116,
#  'war<unk>': -0.5157779895730061,
#  '24th': 0.8705163715468844,
#  'iphonene': 1.969128660214994,
#  'middl': -1.4320687214471612,
#  '*chef': 1.5636635521068298,
#  'redemptiondead': -0.5157779895730061,
#  '(consol': -1.614390278241116,
#  'splatoononlin': 0.8705163715468844,
#  'pushsquarecom': -0.9212430976811705,
#  '"i\'m': 0.17736919098693915,
#  '“chicken': -0.9212430976811705,
#  '"credo': -0.5157779895730061,
#  '"express': -0.9212430976811705,
#  'backvand': -0.5157779895730061,
#  '"not': 1.0936599228610941,
#  'qcguussp2i': 1.2759814796550488,
#  'aboard': 2.5752644637853095,
#  'shadowvers': -1.768540958068374,
#  "what'v": 0.8705163715468844,
#  'torch': -0.5157779895730061,
#  'vs': 0.7209846375759207,
#  'af': -0.46020813841819547,
#  'trimming:': -0.5157779895730061,
#  'roundfast': 0.8705163715468844,
#  'lastmatch': -0.5157779895730061,
#  '7]': -0.5157779895730061,
#  'dabz5': -1.2089251701329515,
#  'sreleas': 0.8705163715468844,
#  '"mi': 2.256810732666775,
#  '25%': -1.768540958068374,
#  'btg5ua7oo4': 1.2759814796550488,
#  'photos:': -0.5157779895730061,
#  'redeeminglik': 0.8705163715468844,
#  '6-10': -1.614390278241116,
#  'eagam': -0.5157779895730061,
#  'text': 0.08499587085592393,
#  'cafduti': -0.22809591712122523,
#  'go”': 1.5636635521068298,
#  'vaarcangel80': -0.5157779895730061,
#  'affair': 0.8705163715468844,
#  'lurkforc': 1.2759814796550488,
#  'publ': -0.5157779895730061,
#  'lowblow': 1.7868071034210395,
#  'lastencount': -0.5157779895730061,
#  "mw'": -1.4320687214471612,
#  'redeemingsound': 0.8705163715468844,
#  'awfuldefinit': 0.8705163715468844,
#  'pictwittercom/ewkym14xot': -1.2089251701329515,
#  'episodefeel': 0.8705163715468844,
#  'wildlif': 0.17736919098693915,
#  'wo7ntzsgnl': -0.5157779895730061,
#  'retir': 0.17736919098693915,
#  '500k+': -1.2089251701329515,
#  '—>': 0.8705163715468844,
#  'whoop': 1.969128660214994,
#  "warner'": 0.8705163715468844,
#  'xaoxjwfvc0': -0.5157779895730061,
#  'maypubg': 0.8705163715468844,
#  'onedr': -1.768540958068374,
#  'pictwittercom/nea45ihuvo': 1.5636635521068298,
#  'd97b': -0.9212430976811705,
#  'shadolad': -0.5157779895730061,
#  'bribesmillion': 1.2759814796550488,
#  'bathtak': 0.8705163715468844,
#  'bswndungbn': -0.5157779895730061,
#  'ubisd': 0.8705163715468844,
#  'rendezv': -0.5157779895730061,
#  'خلاص<unk>': 0.8705163715468844,
#  'waitingbusi': -0.5157779895730061,
#  '(52)': 0.8705163715468844,
#  'lehman': 1.5636635521068298,
#  'struggl': -0.6901313767177838,
#  'hesson': -0.5157779895730061,
#  "that'm": 0.8705163715468844,
#  'antitrust': -2.1252159020071066,
#  '"now': -2.0198553863492803,
#  'annoyingli': -0.5157779895730061,
#  'assasin’': 1.5636635521068298,
#  'health:': -0.5157779895730061,
#  'ny2k': -0.5157779895730061,
#  'beverli': 1.969128660214994,
#  '[code100]': -1.614390278241116,
#  'overwatch': 0.4143976620203687,
#  'home<unk>': -1.4320687214471612,
#  'youtube/vrnevnlcov8': -1.2089251701329515,
#  'outdon': 1.969128660214994,
#  'wheel': -0.22809591712122523,
#  'similar': 0.17736919098693915,
#  'theinch': -0.5157779895730061,
#  'debacl': -2.0198553863492803,
#  'kiz': -1.2089251701329515,
#  'iffi': -1.4320687214471612,
#  'firefight': 1.7868071034210395,
#  '"random': -1.2089251701329515,
#  'xilcp0xjf5': -0.5157779895730061,
#  'pictwittercom/fn06vtyb3i': 1.5636635521068298,
#  'chairman': -1.768540958068374,
#  'robang592': 1.2759814796550488,
#  ':ddddd': 1.2759814796550488,
#  'kazo': -1.614390278241116,
#  'ballot': 0.8705163715468844,
#  '20th': 1.2759814796550488,
#  'afrcom/policy/economy…': -0.5157779895730061,
#  '3jqggscd': 0.8705163715468844,
#  'crunch': -1.614390278241116,
#  'pictwittercom/mfab4xqdst': -1.2089251701329515,
#  'kombat4': 1.7868071034210395,
#  'non-amazon': -0.5157779895730061,
#  'yhrybjdynn': 1.2759814796550488,
#  'wish': 0.6359441244090519,
#  'ta': -0.11031288146484189,
#  'tame': -1.614390278241116,
#  'creditworthi': -0.9212430976811705,
#  'lilia-tyan': 1.5636635521068298,
#  '"strong': -1.614390278241116,
#  'jvhe2pocab': 0.8705163715468844,
#  'booti': -1.2089251701329515,
#  'rant': 0.5450939711122565,
#  'awwww': 1.969128660214994,
#  "assassin'to": 0.17736919098693915,
#  'teamlik': -0.5157779895730061,
#  'rouutcom/02/20/2020/thi': 0.8705163715468844,
#  'lindsey': 0.8705163715468844,
#  'logged"': 0.8705163715468844,
#  'battlefieldvia': -0.5157779895730061,
#  'ininfo/2020/07/tech-i': -0.5157779895730061,
#  'pictwittercom/vliobww0si': 1.5636635521068298,
#  'ofandcard': -0.5157779895730061,
#  '2060': 1.2759814796550488,
#  'on/pictwittercom': 0.8705163715468844,
#  'lolesport': 0.17736919098693915,
#  'led': 0.31090058361146194,
#  '2atv2tc': 1.5636635521068298,
#  'borderlandsy': 0.8705163715468844,
#  'faith': 0.0720086753291129,
#  'herebi': 1.969128660214994,
#  'storm': 1.0753107841928977,
#  '12:00': 1.2759814796550488,
#  'marketin': 0.8705163715468844,
#  "hateage'": -0.5157779895730061,
#  'сиюля': 0.8705163715468844,
#  'hawkinz': -0.5157779895730061,
#  'sick': -0.7433561379550818,
#  'theremast': -0.5157779895730061,
#  'errors:': -0.9212430976811705,
#  ':a': -0.5157779895730061,
#  '4fmmd6ap1w': 1.2759814796550488,
#  'settlement': -0.6980995463669608,
#  'wrap': 2.8854193920891493,
#  'byand': 2.1232793400422523,
#  'time"': -1.4320687214471612,
#  'are:': -1.614390278241116,
#  'pictwittercom/m7vwf1chlc': -1.2089251701329515,
#  'vaughn': 1.969128660214994,
#  'zfor5': 0.8705163715468844,
#  "hell't": -0.5157779895730061,
#  'devil': 0.40051274230114886,
#  'mea': 1.7868071034210395,
#  'bounti': 0.8705163715468844,
#  'manoeuvr': -0.5157779895730061,
#  '9tflop': 0.8705163715468844,
#  'laps': -0.5157779895730061,
#  '0-input': -0.5157779895730061,
#  'they<unk>': 1.2759814796550488,
#  'loonngg<unk>': 0.8705163715468844,
#  'phone': -0.9919439115132781,
#  'presum': 1.2759814796550488,
#  'picfactnmb1pvow': -0.5157779895730061,
#  'contempl': -0.5157779895730061,
#  'cod:': -0.9212430976811705,
#  'season': 0.5675668269643152,
#  'demon’': -0.9212430976811705,
#  'trivia': -1.768540958068374,
#  'itworthless': -1.4320687214471612,
#  '"marco': 1.969128660214994,
#  '(sadly)': -1.2089251701329515,
#  'ranger': 1.2759814796550488,
#  'rhsrmahxghm': 1.5636635521068298,
#  'tiersskin': 0.8705163715468844,
#  'redemptiona': 1.5636635521068298,
#  'onpoint': -1.614390278241116,
#  'midterm': -1.2089251701329515,
#  'afr': -1.9020723506928967,
#  'sht': -0.15910304563427377,
#  'fixft': -1.614390278241116,
#  'youtubecom/watchv=dvbepr…': 1.2759814796550488,
#  'drowned:': -0.5157779895730061,
#  'keirethlol': 0.8705163715468844,
#  'redemptionbroth': 1.7868071034210395,
#  'landiand': -1.614390278241116,
#  'curl': -0.5157779895730061,
#  'rode': -1.4320687214471612,
#  'fuel': 0.17736919098693915,
#  'sudden': -0.00495236580701547,
#  'bastard': -1.1348171979792299,
#  'strimmer': 0.8705163715468844,
#  'ibkerw': -0.9212430976811705,
#  'razorbluecom': 1.2759814796550488,
#  '(brows': 1.7868071034210395,
#  'extraordinari': 1.8821172832253643,
#  'block': -1.5786721956390366,
#  'creeditt': 0.8705163715468844,
#  'yxr85rn3zr': 1.2759814796550488,
#  'arehundr': 0.8705163715468844,
#  'accommod': -0.5157779895730061,
#  'ghostrecon': -0.9664996892692913,
#  'screw': -1.5090297625832896,
#  'welrod': 1.969128660214994,
#  'vineboytv': 0.8705163715468844,
#  'vpn': 0.35969074778089355,
#  'incsgo': 0.8705163715468844,
#  'superior': -1.3807754270596106,
#  'magistrate<unk>': -0.5157779895730061,
#  'hmmmfifagon': -0.5157779895730061,
#  'unrank': -0.864084683841222,
#  'reviewid': 1.5636635521068298,
#  'pastday': -0.2926344382587965,
#  '12tf': 1.969128660214994,
#  'samsclub': 1.2759814796550488,
#  'combo': 1.9926591576251884,
#  'serverstim': -1.4320687214471612,
#  'sirmi': -1.2089251701329515,
#  'hearthston': 0.5970694149169754,
#  'overpsn': -0.5157779895730061,
#  'shgame': -0.9212430976811705,
#  'injohnson': -1.614390278241116,
#  'it_': -1.2089251701329515,
#  'wip': 2.256810732666775,
#  'bday': 1.7868071034210395,
#  'anytim': -0.22809591712122537,
#  'twin': -2.3875801664745975,
#  'mewii': 0.8705163715468844,
#  'storyreason': -0.5157779895730061,
#  'king4': 0.8705163715468844,
#  'tall': 1.5636635521068298,
#  'effici': 2.0491713678885306,
#  'hood': -2.3875801664745975,
#  'willingli': 1.5636635521068298,
#  'understood': 0.5828342990951034,
#  'entrepreneur': 0.8705163715468844,
#  'bounc': 0.7369849789223617,
#  'apexad': -0.5157779895730061,
#  'hearthpwn': 1.2759814796550488,
#  'onehour': 0.8705163715468844,
#  'gta6': 0.8705163715468844,
#  'synchronis': -1.4320687214471612,
#  'shockingli': 1.969128660214994,
#  '18+': 1.2759814796550488,
#  'auto-sprint': -0.9212430976811705,
#  'home-depot-eri': -0.9212430976811705,
#  'renovationne': -0.5157779895730061,
#  'leaver': 1.7868071034210395,
#  'emi': -1.614390278241116,
#  'mob': 0.17736919098693915,
#  'bland': -1.614390278241116,
#  'amazing:)': 0.8705163715468844,
#  '"for': 0.17736919098693915,
#  '🙂': 0.5828342990951034,
#  'evolut': -0.11031288146484189,
#  'junkratt': 1.7868071034210395,
#  'cappingproplayersallday': 0.8705163715468844,
#  'loveokstore/best-online-sh…': 1.2759814796550488,
#  'r6esport': -0.9212430976811705,
#  'tonight<unk>': 0.8705163715468844,
#  'tryna': 0.7006173347514868,
#  '"shut': -0.5157779895730061,
#  'mayan': 0.8705163715468844,
#  'jane': -0.5157779895730061,
#  'difficult)': -1.2089251701329515,
#  'consumerth': 0.8705163715468844,
#  'mother': 0.7651558558890582,
#  'deploy': 0.17736919098693915,
#  'momentum': 0.5138414276081519,
#  'mcdonald': 2.1232793400422523,
#  'kickback': -1.614390278241116,
#  'look/feel': 0.8705163715468844,
#  'forrestgam': 1.2759814796550488,
#  'knights<unk>': 0.8705163715468844,
#  'borderlandsget': 0.8705163715468844,
#  'punkon': 0.8705163715468844,
#  'gleamio/pcfsn/the-r': 0.8705163715468844,
#  'anotherproblem': -0.5157779895730061,
#  'zero-day"': -1.2089251701329515,
#  'keanu"': -1.4320687214471612,
#  'royalestream': 1.2759814796550488,
#  'jokes:': -0.9212430976811705,
#  '35am': -0.9212430976811705,
#  'gdea-ya': 0.8705163715468844,
#  'me"': 1.4766521751172,
#  'glureau': -1.2089251701329515,
#  'pictwittercom/vql4qfukva': 1.5636635521068298,
#  'devilishli': 0.17736919098693915,
#  'unforgiven': 1.7868071034210395,
#  'outcom': -1.3267082057893347,
#  'saron': -0.11031288146484189,
#  "hearthstone'": -0.738921540887216,
#  'clip:': 0.8705163715468844,
#  'yearal': 0.8705163715468844,
#  'louder': 1.2759814796550488,
#  'greatth': -0.5157779895730061,
#  'varzon': 0.8705163715468844,
#  'onlyh': -0.5157779895730061,
#  'arcad': -0.07394523729396708,
#  'this)': 0.8705163715468844,
#  'smoke': 1.1467697481750427,
#  'patrol': 0.8705163715468844,
#  '7e4e4gpm44': 1.2759814796550488,
#  'sap': 0.8705163715468844,
#  'hologram': -1.614390278241116,
#  'franchis': 0.23143641225721487,
#  'twitter:go': -0.5157779895730061,
#  'obvious': -0.34872390490983984,
#  '70%': -0.6699286694002644,
#  'cyberpunka': 0.17736919098693915,
#  'day': 0.452741768967431,
#  'worktim': -1.614390278241116,
#  'techslashdotorg/story/20/02/09…': -0.9212430976811705,
#  'life:': 1.7868071034210395,
#  'crouches)': -0.5157779895730061,
#  'problems:': -1.2089251701329515,
#  'twitterhappi': 0.8705163715468844,
#  'hour://01:': 0.8705163715468844,
#  'happened/happen': 1.5636635521068298,
#  'jjvjdfnvjldf': -1.2089251701329515,
#  'motherhood': -0.5157779895730061,
#  'surg': -1.4320687214471612,
#  'donat': -0.01678682345401838,
#  'industri': -0.1591030456342739,
#  '3-2': 1.969128660214994,
#  'bmx': 2.1232793400422523,
#  'ingam': -0.22809591712122537,
#  'qualif': 1.2759814796550488,
#  'warfareskatelego': 1.5636635521068298,
#  'whitney': 0.8705163715468844,
#  'fallout:': 1.7868071034210395,
#  'fic': -2.0198553863492803,
#  '19': -0.738921540887216,
#  '"caus': 0.8705163715468844,
#  'optu': 1.2759814796550488,
#  'redeemingveri': -0.5157779895730061,
#  "doesn'll": -0.5157779895730061,
#  'horsepow': 0.8705163715468844,
#  '<<<': 1.2759814796550488,
#  'inbut<unk>': -0.5157779895730061,
#  'hype)': 1.7868071034210395,
#  "1'": 1.2759814796550488,
#  'easportsfifaif': -0.5157779895730061,
#  '15:pm': -0.5157779895730061,
#  '/ebaycom/rover/1/711-53…': 0.8705163715468844,
#  'ubisjk': -0.5157779895730061,
#  'guildless': -1.4320687214471612,
#  'duty:': 0.9364743393386818,
#  'help-cent': 1.2759814796550488,
#  'lsykavdgi': 0.8705163715468844,
#  'browser': -1.403081184573909,
#  'borderlandsi': 1.7459851089007843,
#  'fuller': -0.5157779895730061,
#  'quebec': 2.1232793400422523,
#  "users'": -1.2089251701329515,
#  'gmailcom': 0.8705163715468844,
#  'behind': -0.6053901482626932,
#  'scfuzjbgk': -0.5157779895730061,
#  'dose': 0.5450939711122565,
#  'poni': -1.4320687214471612,
#  'spare': -1.2889678778064881,
#  'camera': -0.05901958707729134,
#  'luka': -1.614390278241116,
#  'playstationproperli': -1.4320687214471612,
#  'breakingnewsonlineinfo': -0.5157779895730061,
#  '500<unk>': -0.5157779895730061,
#  'openedsingl': -1.4320687214471612,
#  'remov': -1.601486873405208,
#  'githubcom': -0.9212430976811706,
#  '"strategist': -0.5157779895730061,
#  'yanni': -1.768540958068374,
#  'georg': -1.2089251701329515,
#  'siya': 2.1232793400422523,
#  "bbc'": 0.8705163715468844,
#  'anymor': -1.1979960996007613,
#  'what': -3.256618013498207,
#  'battlepass': -3.2883667118127873,
#  'dotapr': -1.2089251701329515,
#  'fluffbrawl': 1.2759814796550488,
#  'sleight': 1.7868071034210395,
#  'fifafrom': 0.8705163715468844,
#  'battlefieldandth': -0.5157779895730061,
#  'nvidia-ded': -0.5157779895730061,
#  'cutter': 1.2759814796550488,
#  'costrik': 0.8705163715468844,
#  'templat': -0.5157779895730061,
#  'porch': 0.8705163715468844,
#  'updating:': -0.5157779895730061,
#  "ela'": -1.768540958068374,
#  '20ass': -0.5157779895730061,
#  '3be/kmbvee_clm0': 0.8705163715468844,
#  '2015:go': 0.8705163715468844,
#  'dynamicsincreas': 0.8705163715468844,
#  '70': 1.2759814796550488,
#  'resourc': -2.2205260818114314,
#  'gonna': 0.6628770067686399,
#  'f\\357mbp': -0.5157779895730061,
#  'pharma': -1.2089251701329515,
#  'cardpvp': 0.8705163715468844,
#  'pictwittercom/jkn8p8x8zv': -1.2089251701329515,
#  'z390-agig': 1.7868071034210395,
#  'youtubeindia': 0.17736919098693915,
#  'incom/jabulanimthomb': 0.8705163715468844,
#  'leather': 0.8705163715468844,
#  'amt': -1.2089251701329515,
#  'mlssmahut': 0.8705163715468844,
#  'offense:': 0.8705163715468844,
#  "it'sam": -0.5157779895730061,
#  'love:))': 1.2759814796550488,
#  'pr4': -1.4320687214471612,
#  'champ<unk>': 0.8705163715468844,
#  'nosandwith': 0.8705163715468844,
#  'voic': 0.5301905656096815,
#  'creedlook': 1.5636635521068298,
#  "please'v": -0.5157779895730061,
#  'twittercom/realdonaldtrum…': -1.2089251701329515,
#  'selfi': -0.22809591712122523,
#  'redeemingwa': 1.2759814796550488,
#  '9huhskdbph': 0.8705163715468844,
#  'dyingthes': 0.8705163715468844,
#  'souvenirs]': 0.8705163715468844,
#  ...}

# %%
train[2].value_counts(normalize=True)
# Out:
# 2
# Negative    0.519796
# Positive    0.480204
# Name: proportion, dtype: float64

# %%
T_pos= 0.480204
T_neg = 0.519796

prior = math.log (T_pos/T_neg)

# %%
def Naive_Bayes(Tweet):
    sum = prior
    for word in Tweet:
        sum += cond_prob.get(word,0)
    if sum>0:
        return True
    else:
        return False

# %%
y_pred = [Naive_Bayes(tweet) for tweet in clean_tweets]

# %% [markdown]
# ## **Testing the Model**

# %%
print(f"Accuracy: {(accuracy_score(labels,y_pred)*100).round()} %")
# Out:
# Accuracy: 90.0 %

# %%
def Sentiment_Analysis(string):
    clean_text(string)
    process_sentence(string)
    if Naive_Bayes(string):
        print("Positive Statemenet")
    else:
        print("Negative Statemenent")

# %%
Sentiment_Analysis("I want to kill you")
# Out:
# Negative Statemenent

# %%
Sentiment_Analysis("I love you")
# Out:
# Positive Statemenet
